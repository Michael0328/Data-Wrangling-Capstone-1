# %% [markdown]
# # Data Wrangling of Capstone 1

# %% [markdown]
# ## 1 Import Metadata and sunroof project data using pandas csv function
# ## 2 Output metadata and check out the description for each field
# ## 3 Check the shape of each dataframe
# ## 4 Print the info of each dataframe and check if there are any missing values in each     columns
# ## 5 Use dropna() to get rid of each the missing values
# ## 6 Compare median and mean of each column, if they are close which means there is no outliers

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Import Metadata and sunroof data

# %%
metadata=pd.read_csv("metadata.csv")
sunroof_city_old=pd.read_csv("project-sunroof-city-02252018.csv")
sunroof_county_old=pd.read_csv("project-sunroof-county-02252018.csv")
sunroof_postalcode_old=pd.read_csv("project-sunroof-postal_code-02252018.csv")
sunroof_state_old=pd.read_csv("project-sunroof-state-02252018.csv")

# %% [markdown]
# ## Show Metadata which include description of each column

# %%
metadata
# Out:
#                                    Field  \
# 0                            region_name
# 1                        count_qualified
# 2                        percent_covered
# 3                      percent_qualified
# 4   yearly_sunlight_kwh_kw_threshold_avg
# 5              yearly_sunlight_kwh_total
# 6                  yearly_sunlight_kwh_f
# 7                  yearly_sunlight_kwh_n
# 8                  yearly_sunlight_kwh_e
# 9                  yearly_sunlight_kwh_s
# 10                 yearly_sunlight_kwh_w
# 11                number_of_panels_total
# 12                    number_of_panels_f
# 13                    number_of_panels_n
# 14                    number_of_panels_e
# 15                    number_of_panels_s
# 16                    number_of_panels_w
# 17             carbon_offset_metric_tons
# 18               number_of_panels_median
# 19            yearly_sunlight_kwh_median
# 20          install_size_kw_buckets_json
# 21                               lat_avg
# ...

# %% [markdown]
# The sun roof data for each state has 52 rows and 31 columns

# %%
print(sunroof_state_old.shape)
# Out:
# (52, 31)

# %%
print(sunroof_state_old.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 31 columns):
# region_name                             51 non-null object
# state_name                              51 non-null object
# lat_max                                 52 non-null float64
# lat_min                                 52 non-null float64
# lng_max                                 52 non-null float64
# lng_min                                 52 non-null float64
# lat_avg                                 52 non-null float64
# lng_avg                                 52 non-null float64
# yearly_sunlight_kwh_kw_threshold_avg    52 non-null float64
# count_qualified                         52 non-null int64
# percent_covered                         52 non-null float64
# percent_qualified                       52 non-null float64
# number_of_panels_n                      52 non-null int64
# number_of_panels_s                      52 non-null int64
# ...

# %% [markdown]
# There are 19 columns with float data, 9 columns with integer data and 3 with object data

# %%
print(sunroof_city_old.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7930 entries, 0 to 7929
# Data columns (total 31 columns):
# region_name                             7928 non-null object
# state_name                              7929 non-null object
# lat_max                                 7930 non-null float64
# lat_min                                 7930 non-null float64
# lng_max                                 7930 non-null float64
# lng_min                                 7930 non-null float64
# lat_avg                                 7930 non-null float64
# lng_avg                                 7930 non-null float64
# yearly_sunlight_kwh_kw_threshold_avg    7929 non-null float64
# count_qualified                         7930 non-null int64
# percent_covered                         7930 non-null float64
# percent_qualified                       7930 non-null float64
# number_of_panels_n                      7930 non-null int64
# ...

# %% [markdown]
# -  there are some missing values in some columns so I will get rid of these missing values

# %%
print(sunroof_city_old.dropna().info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7897 entries, 0 to 7929
# Data columns (total 31 columns):
# region_name                             7897 non-null object
# state_name                              7897 non-null object
# lat_max                                 7897 non-null float64
# lat_min                                 7897 non-null float64
# lng_max                                 7897 non-null float64
# lng_min                                 7897 non-null float64
# lat_avg                                 7897 non-null float64
# lng_avg                                 7897 non-null float64
# yearly_sunlight_kwh_kw_threshold_avg    7897 non-null float64
# count_qualified                         7897 non-null int64
# percent_covered                         7897 non-null float64
# percent_qualified                       7897 non-null float64
# number_of_panels_n                      7897 non-null int64
# ...

# %% [markdown]
# -  Now all columns don't have missing values

# %%
print(sunroof_state_old.describe())
# Out:
#          lat_max    lat_min     lng_max     lng_min    lat_avg     lng_avg  \
# count  52.000000  52.000000   52.000000   52.000000  52.000000   52.000000
# mean   41.475947  37.316719  -90.811900  -97.249041  39.262400  -93.647265
# std     6.826461   5.928775   17.842720   21.184375   6.057357   19.176842
# min    22.230181  19.002604 -154.815044 -176.657408  21.135301 -157.507901
# 25%    36.998694  33.555723 -102.345209 -109.022966  35.573678 -105.479352
# 50%    41.865188  37.902854  -87.814560  -92.156558  39.836886  -89.196456
# 75%    45.012366  41.357533  -76.547649  -83.096516  42.640260  -79.102298
# max    71.335131  51.851636  -66.950626  -71.042872  61.374116  -69.885662
#
#        yearly_sunlight_kwh_kw_threshold_avg  count_qualified  percent_covered  \
# count                             52.000000     5.200000e+01        52.000000
# mean                            1071.777030     8.948120e+05        60.881147
# ...
